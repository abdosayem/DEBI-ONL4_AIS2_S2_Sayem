# %%
x= 21 
print("My age is",x)
# Out:
# My age is 21

# %%
name = "abdo"
age = 21
course = "ML"
print(f"my name is {name} ,and i am {age} years old ,I am engaged in learning {course }")
# Out:
# my name is abdo ,and i am 21 years old ,I am engaged in learning ML

# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
x = "DEPI"
x[0:2:1]
# Out:
# 'DE'

# %%
name ="depi learning"
upper_txt = name.upper()
print(upper_txt)
# Out:
# DEPI LEARNING

# %%
lower_txt = upper_txt.lower()
lower_txt
# Out:
# 'depi learning'

# %%
name.replace("depi","depi_ml")
# Out:
# 'depi_ml learning'

# %%
name ="depi learning for machine learning depi"
#name.count("depi")
x = name.split()

# %%
print("welcome to depi \"machine learning course\"")
# Out:
# welcome to depi "machine learning course"

# %%
list_one=[1,2,3,4,"depi","learning",True,[1,2,3,"true",["ml","dl","ds"]]]

# %%
list_one[7][4][0]="DS"
list_one
# Out:
# [1, 2, 3, 4, 'depi', 'learning', True, [1, 2, 3, 'true', ['DS', 'dl', 'ds']]]

# %%
name = input('enter your name')
id = input ('enter your id ')
print (f"my name is {name} , my id is {id}")

# %%
input_list = ["depi","learning","python"]
item = input ("enter item in the list")
input_list.remove(item)
print(f"output list = {input_list}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 input_list = ["depi","learning","python"]
# ----> 2 item = input ("enter item in the list")
#       3 input_list.remove(item)
#       4 print(f"output list = {input_list}")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
# ...

# %%
num_1 = float(input("enter first num"))
num_2 = float(input("enter second num"))

print(f"summation : {num_1+num_2}")
print(f"subtraction : {num_1-num_2}")
print(f"mul : {num_1*num_2}")
print(f"div : {num_1/num_2}")
# Out:
# summation : 20.0
# subtraction : 10.0
# mul : 75.0
# div : 3.0

# %%
print("mm")
# Out:
# mm

# %%
a = 10 
b = 5
result = a+b if a > b else a - b 
print(result)
# Out:
# 15

# %%
age = 8
print("Adult") if age >= 18 else (print("teenager") if age >=13 else print("Child"))
# Out:
# Child

# %%
is_sunny = True
tem = 25
if is_sunny:
    print("A Sunny day")
    if tem > 20 :
        print("Warm")
    else:
             print("cool")
else:  
      print("not sunny")
# Out:
# A Sunny day

# %%
grade =int( input ("enter your grade from 100"))
if 0<= grade <= 100:
    if 90<= grade <= 80:
        grade = "A"
    elif 80<= grade <= 40:
        grade = "B"
    elif 80<= grade <= 40:
        grade = "C"
    elif 80<= grade <= 40:
        grade = "D"

# %%
name ="amit"
print(name.split())
# Out:
# ['amit']
